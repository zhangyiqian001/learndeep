# %%
from datasets import load_dataset

data = load_dataset(
    path="wmt14",
    name="fr-en",
    cache_dir="../data",
)
data
# Out:
# Using the latest cached version of the dataset since wmt14 couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'fr-en' at ..\data\wmt14\fr-en\0.0.0\f3c844b69f2e7375 (last modified on Fri Nov 15 14:19:33 2024).
# Loading dataset shards:   0%|          | 0/30 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 40836715
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 3003
#     })
# })

# %%
[i for i in data['test'].data[0][3002].items()]
# Out:
# [('en',
#   <pyarrow.StringScalar: 'The research will address inclusion from every angle: linguistic, educational, social and cultural.'>),
#  ('fr',
#   <pyarrow.StringScalar: "Les recherches porteront sur l'inclusion sous tous ses angles: linguistique, scolaire, social et culturel.">)]

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 40836715
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 3003
#     })
# })
